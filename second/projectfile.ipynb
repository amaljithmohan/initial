# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Github/second
# Out:
# /content/gdrive/My Drive/Github/second

# %%
import numpy as np
import pandas as pd

# %%
test= pd.read_csv('/content/test.csv')
train= pd.read_csv('/content/train.csv')

# %%
test.head()
# Out:
#    id        date  store  item
# 0   0  2018-01-01      1     1
# 1   1  2018-01-02      1     1
# 2   2  2018-01-03      1     1
# 3   3  2018-01-04      1     1
# 4   4  2018-01-05      1     1

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Github/second

# %%
import os
os.chdir('/content/gdrive/My Drive/Github/second')

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Github/second
